# %% [markdown]
# ## Q3.

# %%
guest_book = """김갑,123456789
이을,010-1234-5678
박병,010-5678-111
최정,111-1111-1111
정무,010-3333-3333"""

# %%
def wrong_guest_book(guest_book):
  # 방명록 txt 파일 생성
  f = open("/content/drive/MyDrive/코칭스터디 12기/방명록.txt", 'w')
  f.close()

  # 엔터를 기준으로 나눠서 리스트 형태로 저장
  guest_book = guest_book.split('\n')
  wrong_list = []
  for line in guest_book:
    name, number = line.split(',')

    if number.count('-') != 2:
      print('잘못 쓴 사람: {}'.format(name))
      print('잘못 쓴 번호: {}\n'.format(number))
      continue

    number1 = number.split('-')

    if number1[0] !='010' or len(number1[1]) != 4 or len(number1[2]) != 4:
      print('잘못 쓴 사람: {}'.format(name))
      print('잘못 쓴 번호: {}\n'.format(number))
      continue

# %%
wrong_guest_book(guest_book)
# Out:
# 잘못 쓴 사람: 김갑
# 잘못 쓴 번호: 123456789
#
# 잘못 쓴 사람: 박병
# 잘못 쓴 번호: 010-5678-111
#
# 잘못 쓴 사람: 최정
# 잘못 쓴 번호: 111-1111-1111
